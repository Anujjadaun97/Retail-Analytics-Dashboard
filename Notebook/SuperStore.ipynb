# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/Superstore.csv", encoding='latin1')

# %%
df
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 1          2  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 2          3  CA-2016-138688   6/12/2016   6/16/2016    Second Class
# 3          4  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# 4          5  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# ...      ...             ...         ...         ...             ...
# 9158    9159  CA-2014-134215    8/4/2014    8/8/2014  Standard Class
# 9159    9160  CA-2016-118934    8/9/2016   8/14/2016  Standard Class
# 9160    9161  CA-2016-118934    8/9/2016   8/14/2016  Standard Class
# 9161    9162  CA-2016-160108   12/8/2016  12/12/2016  Standard Class
# 9162    9163  CA-2016-160108   12/8/2016  12/12/2016  Standard Class
#
#      Customer ID        Customer Name      Segment        Country  \
# 0       CG-12520          Claire Gute     Consumer  United States
# ...

# %%
df.shape
# Out:
# (9163, 21)

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
df.describe()
# Out:
#             Row ID   Postal Code         Sales     Quantity     Discount  \
# count  9163.000000   9163.000000   9162.000000  9162.000000  9162.000000
# mean   4582.000000  55086.249154    230.652025     3.794368     0.156478
# std    2645.274592  32022.327994    633.377709     2.218611     0.206713
# min       1.000000   1040.000000      0.444000     1.000000     0.000000
# 25%    2291.500000  23223.000000     17.442500     2.000000     0.000000
# 50%    4582.000000  55901.000000     54.900000     3.000000     0.200000
# 75%    6872.500000  90004.000000    210.296000     5.000000     0.200000
# max    9163.000000  99301.000000  22638.480000    14.000000     0.800000
#
#             Profit
# count  9162.000000
# mean     29.150366
# std     237.966805
# min   -6599.978000
# 25%       1.731375
# 50%       8.687750
# 75%      29.480550
# max    8399.976000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9163 entries, 0 to 9162
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9163 non-null   int64
#  1   Order ID       9163 non-null   object
#  2   Order Date     9163 non-null   object
#  3   Ship Date      9163 non-null   object
#  4   Ship Mode      9163 non-null   object
#  5   Customer ID    9163 non-null   object
#  6   Customer Name  9163 non-null   object
#  7   Segment        9163 non-null   object
#  8   Country        9163 non-null   object
#  9   City           9163 non-null   object
#  10  State          9163 non-null   object
#  11  Postal Code    9163 non-null   int64
#  12  Region         9163 non-null   object
#  13  Product ID     9163 non-null   object
#  14  Category       9163 non-null   object
#  15  Sub-Category   9163 non-null   object
#  16  Product Name   9163 non-null   object
# ...

# %%
df["Order Date"] = pd.to_datetime(df["Order Date"])
df["Ship Date"] = pd.to_datetime(df["Ship Date"])

# %%
df["Order Date"]
# Out:
# 0      2016-11-08
# 1      2016-11-08
# 2      2016-06-12
# 3      2015-10-11
# 4      2015-10-11
#           ...
# 9158   2014-08-04
# 9159   2016-08-09
# 9160   2016-08-09
# 9161   2016-12-08
# 9162   2016-12-08
# Name: Order Date, Length: 9163, dtype: datetime64[ns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9163 entries, 0 to 9162
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9163 non-null   int64
#  1   Order ID       9163 non-null   object
#  2   Order Date     9163 non-null   datetime64[ns]
#  3   Ship Date      9163 non-null   datetime64[ns]
#  4   Ship Mode      9163 non-null   object
#  5   Customer ID    9163 non-null   object
#  6   Customer Name  9163 non-null   object
#  7   Segment        9163 non-null   object
#  8   Country        9163 non-null   object
#  9   City           9163 non-null   object
#  10  State          9163 non-null   object
#  11  Postal Code    9163 non-null   int64
#  12  Region         9163 non-null   object
#  13  Product ID     9163 non-null   object
#  14  Category       9163 non-null   object
#  15  Sub-Category   9163 non-null   object
#  16  Product Name   9163 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            1
# Quantity         1
# Discount         1
# Profit           1
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['Order Date']
# Out:
# 0      2016-11-08
# 1      2016-11-08
# 2      2016-06-12
# 3      2015-10-11
# 4      2015-10-11
#           ...
# 9158   2014-08-04
# 9159   2016-08-09
# 9160   2016-08-09
# 9161   2016-12-08
# 9162   2016-12-08
# Name: Order Date, Length: 9163, dtype: datetime64[ns]

# %%
df['order_year'] = df['Order Date'].dt.year
df['order_month_number'] = df['Order Date'].dt.month
df['order_month_name'] = df['Order Date'].dt.month_name()

# %%
df['order_quarter'] = df['Order Date'].dt.quarter

# %%
df['profit_margin'] = (df['Profit']/df['Sales'])*100

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9163 entries, 0 to 9162
# Data columns (total 26 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Row ID              9163 non-null   int64
#  1   Order ID            9163 non-null   object
#  2   Order Date          9163 non-null   datetime64[ns]
#  3   Ship Date           9163 non-null   datetime64[ns]
#  4   Ship Mode           9163 non-null   object
#  5   Customer ID         9163 non-null   object
#  6   Customer Name       9163 non-null   object
#  7   Segment             9163 non-null   object
#  8   Country             9163 non-null   object
#  9   City                9163 non-null   object
#  10  State               9163 non-null   object
#  11  Postal Code         9163 non-null   int64
#  12  Region              9163 non-null   object
#  13  Product ID          9163 non-null   object
#  14  Category            9163 non-null   object
# ...

# %%
df['Sales']
# Out:
# 0       261.9600
# 1       731.9400
# 2        14.6200
# 3       957.5775
# 4        22.3680
#           ...
# 9158    255.4200
# 9159      4.3380
# 9160     11.8800
# 9161    405.8600
# 9162         NaN
# Name: Sales, Length: 9163, dtype: float64

# %%
print("Total Sales")
print(round(df['Sales'].sum(),2))
print("Avg Sales")
print(round(df['Sales'].mean(),2))
print("Max Sales")
print(df['Sales'].max())
print("Min Sales")
print(df['Sales'].min())
# Out:
# Total Sales
# 2113233.85
# Avg Sales
# 230.65
# Max Sales
# 22638.48
# Min Sales
# 0.444

# %%
print("Total Profit")
print(round(df['Profit'].sum(),2))
print("Avg Profit")
print(round(df['Profit'].mean(),2))
print("Max Profit")
print(df['Profit'].max())
print("Min Profit")
print(df['Profit'].min())
# Out:
# Total Profit
# 267075.65
# Avg Profit
# 29.15
# Max Profit
# 8399.976
# Min Profit
# -6599.978

# %%
print("Avg Discount")
print(df['Discount'].mean())
print("Max Discount")
print(df['Discount'].max())
print("Min Discount")
print(df['Discount'].min())
# Out:
# Avg Discount
# 0.1564778432656625
# Max Discount
# 0.8
# Min Discount
# 0.0

# %%
plt.figure(figsize=(10,5))
plt.hist(df['Sales'])
plt.title('Sales Distribution')
plt.xlabel('Sales')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.hist(df['Profit'])
plt.title('Profit Distribution')
plt.xlabel('Profit')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.hist(df['Discount'])
plt.title('Discount Distribution')
plt.xlabel('Discount')
plt.ylabel('Frequency')
plt.show()

# %%
df['Discount'].corr(df['Profit'])
# Out:
# np.float64(-0.21740997257207087)

# %%
plt.figure(figsize=(10,5))
plt.scatter(
    df['Discount'],
    df['Profit'],
    alpha=.05,
    color='red'
)
plt.title('Discount vs Profit')
plt.xlabel('Discount')
plt.ylabel('Profit')
plt.show()

# %%
df.groupby('Discount')['Profit'].mean().sort_index()
# Out:
# Discount
# 0.00     68.328841
# 0.10     98.162910
# 0.15     25.156894
# 0.20     24.179917
# 0.30    -46.743033
# 0.32    -96.041355
# 0.40   -106.067939
# 0.45   -226.646464
# 0.50   -321.185102
# 0.60    -42.577926
# 0.70    -98.801802
# 0.80    -93.529756
# Name: Profit, dtype: float64

# %%
profit_discount =profit_discount = (
    df.groupby('Discount')['Profit']
      .mean()
      .reset_index()
)

# %%
plt.figure(figsize=(10,5))
plt.plot(profit_discount)
plt.title('Discount vs Profit')
plt.xlabel('Discount')
plt.ylabel('Profit')
plt.show()
#

# %%
plt.figure(figsize=(10,5))
sns.boxplot(
    data=df,
    x='Discount',
    y='Profit'
)
plt.title('Discount vs Profit')
plt.xlabel('Discount')
plt.ylabel('Profit')
# Out:
# Text(0, 0.5, 'Profit')

# %%
loss_orders = df.groupby('Discount')['Profit'].apply(lambda x: (x < 0).mean() * 100)
print(loss_orders)
# Out:
# Discount
# 0.00      0.000000
# 0.10      3.658537
# 0.15     33.333333
# 0.20     13.770492
# 0.30     91.346154
# 0.32    100.000000
# 0.40     87.765957
# 0.45    100.000000
# 0.50    100.000000
# 0.60    100.000000
# 0.70    100.000000
# 0.80    100.000000
# Name: Profit, dtype: float64

# %%
df['Category'].value_counts()
# Out:
# Category
# Office Supplies    5514
# Furniture          1942
# Technology         1707
# Name: count, dtype: int64

# %%
df.groupby('Category')['Sales'].sum().sort_values(ascending=False)
# Out:
# Category
# Technology         787961.4090
# Furniture          669047.5747
# Office Supplies    656224.8660
# Name: Sales, dtype: float64

# %%
df.groupby('Category')['Profit'].sum().sort_values(ascending=False)
# Out:
# Category
# Technology         137669.9376
# Office Supplies    113780.2922
# Furniture           15625.4195
# Name: Profit, dtype: float64

# %%
df.groupby('Category')['profit_margin'].mean().sort_values(ascending=False)
# Out:
# Category
# Technology         15.607189
# Office Supplies    13.739335
# Furniture           3.792441
# Name: profit_margin, dtype: float64

# %%
df.groupby('Sub-Category')['Sales'].sum().sort_values(ascending=False).head(10)
# Out:
# Sub-Category
# Phones         301993.6460
# Chairs         296104.9010
# Storage        204294.0080
# Tables         190325.5880
# Machines       183470.9690
# Binders        180746.7810
# Accessories    157148.6820
# Copiers        145348.1120
# Bookcases       99442.1617
# Appliances      99113.9670
# Name: Sales, dtype: float64

# %%
df.groupby('Sub-Category')['Profit'].sum().sort_values(ascending=False).head(10)
# Out:
# Sub-Category
# Copiers        54435.8480
# Phones         40471.5908
# Accessories    39790.7376
# Paper          31431.6221
# Binders        28840.8762
# Chairs         24293.5408
# Storage        19900.2915
# Appliances     16348.6735
# Furnishings    11796.9659
# Envelopes       6564.5688
# Name: Profit, dtype: float64

# %%
df.groupby('Sub-Category')['Profit'].sum().sort_values(ascending=False).tail(10)
# Out:
# Sub-Category
# Appliances     16348.6735
# Furnishings    11796.9659
# Envelopes       6564.5688
# Art             5929.8899
# Labels          5043.0425
# Machines        2971.7612
# Fasteners        899.5939
# Supplies       -1178.2662
# Bookcases      -3987.7148
# Tables        -16477.3724
# Name: Profit, dtype: float64

# %%
df.groupby('Region')['Sales'].sum().sort_values(ascending=False)
# Out:
# Region
# West       659506.6835
# East       615477.9240
# Central    465667.2412
# South      372582.0010
# Name: Sales, dtype: float64

# %%
df.groupby('Region')['Profit'].sum().sort_values(ascending=False)
# Out:
# Region
# West       98431.9692
# East       82318.1762
# South      44991.0819
# Central    41334.4220
# Name: Profit, dtype: float64

# %%
df.groupby('Region')['profit_margin'].sum().sort_values(ascending=False)
# Out:
# Region
# West       63469.544118
# East       43025.642857
# South      24687.250000
# Central   -21421.142157
# Name: profit_margin, dtype: float64

# %%
df.groupby('State')['Sales'].sum().sort_values(ascending=False).head(10)
# Out:
# State
# California      408566.9505
# New York        278717.1810
# Texas           155151.7162
# Washington      126877.9840
# Pennsylvania    107513.1200
# Florida          85231.4080
# Illinois         75318.2790
# Michigan         73506.9460
# Ohio             69444.5480
# Virginia         67175.4100
# Name: Sales, dtype: float64

# %%
df.groupby('State')['Profit'].sum().sort_values(ascending=False).head(10)
# Out:
# State
# California    68273.6184
# New York      67164.2078
# Washington    31134.3726
# Michigan      23807.6559
# Virginia      17559.1137
# Indiana       16696.0345
# Georgia       15903.1066
# Minnesota     10640.2718
# Kentucky      10132.5809
# Delaware       9484.2734
# Name: Profit, dtype: float64

# %%
df.groupby('State')['Profit'].sum().sort_values(ascending=False).tail(10)
# Out:
# State
# Oregon            -1336.5407
# Arizona           -2720.8826
# Florida           -3722.9887
# Tennessee         -5335.6761
# North Carolina    -5666.7335
# Colorado          -6541.1834
# Illinois         -11781.0242
# Pennsylvania     -14626.1046
# Ohio             -16622.3457
# Texas            -20497.0315
# Name: Profit, dtype: float64

# %%
df.groupby('Customer Name')['Sales'].sum().sort_values(ascending=False).head(10)
# Out:
# Customer Name
# Sean Miller           24205.606
# Tamara Chand          19052.218
# Raymond Buch          15117.339
# Tom Ashbrook          14588.580
# Adrian Barton         14433.755
# Ken Lonsdale          14153.229
# Sanjit Chand          13831.774
# Hunter Lopez          12873.298
# Sanjit Engle          12209.438
# Christopher Conant    12129.072
# Name: Sales, dtype: float64

# %%
df.groupby('Customer Name')['Profit'].sum().sort_values(ascending=False).head(10)
# Out:
# Customer Name
# Tamara Chand            8981.3239
# Raymond Buch            6976.0959
# Sanjit Chand            5724.3075
# Hunter Lopez            5622.4292
# Adrian Barton           5437.3400
# Tom Ashbrook            4701.7467
# Christopher Martinez    3214.2728
# Keith Dawkins           2933.6706
# Andy Reiter             2884.6208
# Daniel Raglin           2869.0760
# Name: Profit, dtype: float64

# %%
df.groupby('Customer Name')['Order ID'].nunique().sort_values(ascending=False).head(10)
# Out:
# Customer Name
# Zuschuss Carroll       13
# Joel Eaton             13
# Chloris Kastensmidt    13
# Emily Phan             13
# Patrick Gardner        13
# Bart Pistole           12
# Erin Ashbrook          12
# Ken Black              12
# Anna Häberlin          12
# Noel Staavos           12
# Name: Order ID, dtype: int64

# %%
df['Segment'].unique()
# Out:
# array(['Consumer', 'Corporate', 'Home Office'], dtype=object)

# %%
consumerdf = df[df['Segment'] == 'Consumer']
corporatedf = df[df['Segment'] == 'Corporate']
homeoffice = df[df['Segment'] == 'Home Office']

# %%
print("Consmer Total Sales")
print(consumerdf['Sales'].sum())
print("Consmer Avg Sales")
print(consumerdf['Sales'].mean())
print("Consmer Max Sales")
print(consumerdf['Sales'].max())
print("Consmer Min Sales")
print(consumerdf['Sales'].min())
print("Consumer Total Profit")
print(consumerdf['Profit'].sum())
print("Consumer Avg Profit")
print(consumerdf['Profit'].mean())
print("Consumer Max Profit")
print(consumerdf['Profit'].max())
print("Consumer Min Profit")
print(consumerdf['Profit'].min())

print("Consumer Order Count")
print(consumerdf['Order ID'].nunique())

print("Consumer Profit Margin")
consumer_profit_margin = ((consumerdf['Profit'].sum())/(consumerdf['Sales'].sum()))*100
print(consumer_profit_margin)
# Out:
# Consmer Total Sales
# 1055687.9662000001
# Consmer Avg Sales
# 222.15655854377107
# Consmer Max Sales
# 13999.96
# Consmer Min Sales
# 0.444
# Consumer Total Profit
# 126444.05369999999
# Consumer Avg Profit
# 26.608597159090905
# Consumer Max Profit
# 6719.9808
# Consumer Min Profit
# -6599.978
# Consumer Order Count
# 2361
# Consumer Profit Margin
# 11.977407884560954

# %%
print("Corporate Total Sales")
print(corporatedf['Sales'].sum())
print("Corporate Avg Sales")
print(corporatedf['Sales'].mean())
print("Corporate Max Sales")
print(corporatedf['Sales'].max())
print("Corporate Min Sales")
print(corporatedf['Sales'].min())
print("Corporate Total Profit")
print(corporatedf['Profit'].sum())
print("Corporate Avg Profit")
print(corporatedf['Profit'].mean())
print("Corporate Max Profit")
print(corporatedf['Profit'].max())
print("Corporate Min Profit")
print(corporatedf['Profit'].min())

print("Corporate Order Count")
print(corporatedf['Order ID'].nunique())

print("Corporate Profit Margin")
corporate_profit_margin = ((corporatedf['Profit'].sum())/(corporatedf['Sales'].sum()))*100
print(corporate_profit_margin)
# Out:
# Corporate Total Sales
# 651232.1786000001
# Corporate Avg Sales
# 234.25617935251802
# Corporate Max Sales
# 17499.95
# Corporate Min Sales
# 0.836
# Corporate Total Profit
# 82313.51810000002
# Corporate Avg Profit
# 29.609179172661875
# Corporate Max Profit
# 8399.976
# Corporate Min Profit
# -3839.9904
# Corporate Order Count
# 1394
# Corporate Profit Margin
# 12.639657683524671

# %%
print("Home Office Total Sales")
print(homeoffice['Sales'].sum())
print("Home Office Avg Sales")
print(homeoffice['Sales'].mean())
print("Home Office Max Sales")
print(homeoffice['Sales'].max())
print("Home Office Min Sales")
print(homeoffice['Sales'].min())
print("Home Office Total Profit")
print(homeoffice['Profit'].sum())
print("Home Office Avg Profit")
print(homeoffice['Profit'].mean())
print("Home Office Max Profit")
print(homeoffice['Profit'].max())
print("Home Office Min Profit")
print(homeoffice['Profit'].min())

print("Home Office Order Count")
print(homeoffice['Order ID'].nunique())

print("Home Office Profit Margin")
homeoffice_profit_margin = ((homeoffice['Profit'].sum())/(homeoffice['Sales'].sum()))*100
print(homeoffice_profit_margin)
# Out:
# Home Office Total Sales
# 406313.7049
# Home Office Avg Sales
# 249.27221159509205
# Home Office Max Sales
# 22638.48
# Home Office Min Sales
# 0.99
# Home Office Total Profit
# 58318.0775
# Home Office Avg Profit
# 35.77796165644172
# Home Office Max Profit
# 3919.9888
# Home Office Min Profit
# -3399.98
# Home Office Order Count
# 829
# Home Office Profit Margin
# 14.352968358365606

# %%
print("Top 10 Customer Sales Contribution %")
print(((df.groupby('Customer Name')['Sales'].sum().sort_values(ascending=False).head(10).sum())/(df['Sales'].sum()))*100)
# Out:
# Top 10 Customer Sales Contribution %
# 7.2208908172497175

# %%
df['Order Date'].max()
# Out:
# Timestamp('2017-12-30 00:00:00')

# %%
df.head(5)
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#                                         Product Name     Sales Quantity  \
# ...

# %%
snapshot_date = df['Order Date'].max() + pd.Timedelta(days=1)

# %%
rfm_df = df.groupby('Customer Name').agg({
    'Order Date': lambda x: (snapshot_date - x.max()).days,
    'Order ID': 'nunique',
    'Sales': 'sum'
})

# %%
rfm_df.columns = ['Recency', 'Frequency', 'Monetary']

# %%
rfm_df.head(5)
# Out:
#                  Recency  Frequency  Monetary
# Customer Name
# Aaron Bergman        416          3   886.156
# Aaron Hawkins         13          6   753.440
# Aaron Smayling        89          6  2573.026
# Adam Bellavance       55          7  7515.470
# Adam Hart             35         10  3250.337

# %%
rfm_df['R_Score'] = pd.qcut(
    rfm_df['Recency'],
    q=5,
    labels=[5,4,3,2,1]
)

# %%
rfm_df['F_Score'] = pd.qcut(
    rfm_df['Frequency'],
    q=5,
    labels=[1,2,3,4,5]
)

# %%
rfm_df['M_Score'] = pd.qcut(
    rfm_df['Monetary'],
    q=5,
    labels=[1,2,3,4,5]
)

# %%
rfm_df['RFM_Score'] = (
    rfm_df['R_Score'].astype(str) +
    rfm_df['F_Score'].astype(str) +
    rfm_df['M_Score'].astype(str)
)

# %%
rfm_df
# Out:
#                     Recency  Frequency  Monetary R_Score F_Score M_Score  \
# Customer Name
# Aaron Bergman           416          3   886.156       1       1       2
# Aaron Hawkins            13          6   753.440       5       3       1
# Aaron Smayling           89          6  2573.026       3       3       4
# Adam Bellavance          55          7  7515.470       4       4       5
# Adam Hart                35         10  3250.337       4       5       4
# ...                     ...        ...       ...     ...     ...     ...
# Xylona Preis             44         11  2374.658       4       5       3
# Yana Sorensen            10          8  6720.444       5       4       5
# Yoseph Carroll            5          5  5454.350       5       2       5
# Zuschuss Carroll         55         13  8025.707       4       5       5
# Zuschuss Donatelli      203          5  1493.944       2       2       2
#
#                    RFM_Score
# Customer Name
# Aaron Bergman            112
# ...

# %%
def segment(row):

  if row['RFM_Score'] == '555':
    return 'Champion'

  elif row['R_Score'] >= 4 and row['F_Score'] >= 4:
    return 'Loyal Customer'

  elif row['R_Score'] >= 4:
    return 'Potential Loyalists'

  elif row['R_Score'] >= 2:
    return 'At Risk'

  else:
    return 'Lost Customers'

rfm_df['Segment'] = rfm_df.apply(segment, axis=1)

# %%
rfm_df['Segment'].value_counts()
# Out:
# Segment
# At Risk                314
# Potential Loyalists    169
# Lost Customers         158
# Loyal Customer         130
# Champion                18
# Name: count, dtype: int64

# %%
rfm_df.sample(10)
# Out:
#                   Recency  Frequency  Monetary R_Score F_Score M_Score  \
# Customer Name
# Caroline Jumper       190          7  9289.846       2       4       5
# Frank Preis            24          8  4046.746       5       4       5
# Michael Oakman        181          2   154.288       2       1       1
# Michael Nguyen         35          6  2477.946       4       3       3
# Roger Barcio           55          3   297.260       4       1       1
# Shirley Schmidt       492          3   613.400       1       1       1
# Philip Fox            197          6  2770.000       2       3       4
# Kunst Miller          621          7  3638.302       1       4       4
# Bruce Degenhardt       94          6  1526.500       3       3       2
# Richard Bierner        42          7  1864.156       4       4       3
#
#                  RFM_Score              Segment
# Customer Name
# Caroline Jumper        245              At Risk
# Frank Preis            545       Loyal Customer
# ...

# %%
rfm_df.groupby('Segment')['Recency'].mean()
# Out:
# Segment
# At Risk                124.668790
# Champion                12.166667
# Lost Customers         489.721519
# Loyal Customer          29.046154
# Potential Loyalists     27.556213
# Name: Recency, dtype: float64

# %%
rfm_df['R_Score'].value_counts()
# Out:
# R_Score
# 5    162
# 1    158
# 3    157
# 2    157
# 4    155
# Name: count, dtype: int64

# %%
rfm_df['F_Score'].value_counts()
# Out:
# F_Score
# 1    257
# 4    168
# 2    125
# 3    122
# 5    117
# Name: count, dtype: int64

# %%
rfm_df['M_Score'].value_counts()
# Out:
# M_Score
# 1    158
# 2    158
# 4    158
# 5    158
# 3    157
# Name: count, dtype: int64

# %%
rfm_df['Segment'].count()
# Out:
# np.int64(789)

# %%
df.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#                                         Product Name     Sales Quantity  \
# ...

# %%
rfm_df
# Out:
#                     Recency  Frequency  Monetary R_Score F_Score M_Score  \
# Customer Name
# Aaron Bergman           416          3   886.156       1       1       2
# Aaron Hawkins            13          6   753.440       5       3       1
# Aaron Smayling           89          6  2573.026       3       3       4
# Adam Bellavance          55          7  7515.470       4       4       5
# Adam Hart                35         10  3250.337       4       5       4
# ...                     ...        ...       ...     ...     ...     ...
# Xylona Preis             44         11  2374.658       4       5       3
# Yana Sorensen            10          8  6720.444       5       4       5
# Yoseph Carroll            5          5  5454.350       5       2       5
# Zuschuss Carroll         55         13  8025.707       4       5       5
# Zuschuss Donatelli      203          5  1493.944       2       2       2
#
#                    RFM_Score              Segment
# Customer Name
# ...

# %%
#(df.to_csv('sales_data.csv', index=False)
#rfm_df.to_csv('rfm_analysis.csv', index=False)

#from google.colab import files

#files.download('sales_data.csv')
#files.download('rfm_analysis.csv'))

# %%
rfmdf = df.groupby('Customer ID').agg({
    'Order Date': lambda x: (snapshot_date - x.max()).days,
    'Order ID': 'nunique',
    'Sales': 'sum'
})

# %%
rfmdf.columns = ['Recency', 'Frequency', 'Monetary']

# %%
rfmdf['R_Score'] = pd.qcut(
    rfmdf['Recency'],
    q=5,
    labels=[5,4,3,2,1]
)

# %%
rfmdf['F_Score'] = pd.qcut(
    rfmdf['Frequency'],
    q=5,
    labels=[1,2,3,4,5]
)

# %%
rfmdf['M_Score'] = pd.qcut(
    rfmdf['Monetary'],
    q=5,
    labels=[1,2,3,4,5]
)

# %%
rfmdf['RFM_Score'] = (
    rfmdf['R_Score'].astype(str) +
    rfmdf['F_Score'].astype(str) +
    rfmdf['M_Score'].astype(str)
)

# %%
rfmdf.head()
# Out:
#              Recency  Frequency  Monetary R_Score F_Score M_Score RFM_Score
# Customer ID
# AA-10315         185          5  5563.560       2       2       5       225
# AA-10375          20          8   999.530       5       4       2       542
# AA-10480         260          4  1790.512       1       1       3       113
# AA-10645          56          6  5086.935       4       3       5       435
# AB-10015         416          3   886.156       1       1       2       112

# %%
def segment(row):

  if row['RFM_Score'] == '555':
    return 'Champion'

  elif row['R_Score'] >= 4 and row['F_Score'] >= 4:
    return 'Loyal Customer'

  elif row['R_Score'] >= 4:
    return 'Potential Loyalists'

  elif row['R_Score'] >= 2:
    return 'At Risk'

  else:
    return 'Lost Customers'

rfmdf['Segment'] = rfmdf.apply(segment, axis=1)

# %%
rfmdf['Segment'].value_counts()
# Out:
# Segment
# At Risk                314
# Potential Loyalists    169
# Lost Customers         158
# Loyal Customer         130
# Champion                18
# Name: count, dtype: int64

# %%
rfmdf.groupby('Segment')['Recency'].mean()
# Out:
# Segment
# At Risk                124.668790
# Champion                12.166667
# Lost Customers         489.721519
# Loyal Customer          29.046154
# Potential Loyalists     27.556213
# Name: Recency, dtype: float64

# %%
rfmdf['R_Score'].value_counts()
# Out:
# R_Score
# 5    162
# 1    158
# 3    157
# 2    157
# 4    155
# Name: count, dtype: int64

# %%
rfmdf['F_Score'].value_counts()
# Out:
# F_Score
# 1    257
# 4    168
# 2    125
# 3    122
# 5    117
# Name: count, dtype: int64

# %%
rfmdf['M_Score'].value_counts()
# Out:
# M_Score
# 1    158
# 2    158
# 4    158
# 5    158
# 3    157
# Name: count, dtype: int64

# %%
rfmdf
# Out:
#              Recency  Frequency  Monetary R_Score F_Score M_Score RFM_Score  \
# Customer ID
# AA-10315         185          5  5563.560       2       2       5       225
# AA-10375          20          8   999.530       5       4       2       542
# AA-10480         260          4  1790.512       1       1       3       113
# AA-10645          56          6  5086.935       4       3       5       435
# AB-10015         416          3   886.156       1       1       2       112
# ...              ...        ...       ...     ...     ...     ...       ...
# XP-21865          44         11  2374.658       4       5       3       453
# YC-21895           5          5  5454.350       5       2       5       525
# YS-21880          10          8  6720.444       5       4       5       545
# ZC-21910          55         13  8025.707       4       5       5       455
# ZD-21925         203          5  1493.944       2       2       2       222
#
#                          Segment
# ...
